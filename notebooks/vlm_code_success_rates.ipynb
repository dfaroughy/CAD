# %%
import setup_path  # adds project root to sys.path — keep this first
from metrics import code_error_bins, code_pass_rate

# %% [markdown]
# # GPT-4o

# %%
bins = code_error_bins("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/gpt-4o")
r = code_pass_rate("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/gpt-4o")

n_total = sum(info['count'] for info in bins.values())
for etype, info in bins.items():
    print(f"{etype:20s}  {info['fraction']:.1%}  ({info['count']}/{n_total})")

for fname, res in r['results'].items():
    if not res['success']:
        print(f"  FAIL  {fname}  @ {res['error_step']}  {res['error_type']}: {res['error_msg']}")
# Out:
# passed                77.0%  (77/100)
# SyntaxError           13.0%  (13/100)
# ValueError            5.0%  (5/100)
# Standard_Failure      4.0%  (4/100)
# TypeError             1.0%  (1/100)
#   FAIL  20251218_033650_brass_spacer_tube_v1.py  @ result  Standard_Failure: There are no suitable edges for chamfer or fillet
#   FAIL  20251218_033656_keyed_reduced_shaft_v1.py  @ step3  ValueError: If multiple objects selected, they all must be planar faces.
#   FAIL  20251218_033657_beveled_thick_wall_tube_v1.py  @ result  Standard_Failure: There are no suitable edges for chamfer or fillet
#   FAIL  20251218_033658__mounting_v1.py  @ step2  SyntaxError: unexpected EOF while parsing (<string>, line 1)
#   FAIL  20251218_033659__t_handle_lever_v1.py  @ step3  ValueError: If multiple objects selected, they all must be planar faces.
#   FAIL  20251218_033659_standoff_spacer_type_v1.py  @ result  Standard_Failure: There are no suitable edges for chamfer or fillet
# ...

# %% [markdown]
# # Gemma-3

# %%
bins = code_error_bins("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/gemma-3-27b-it")
r = code_pass_rate("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/gemma-3-27b-it")

n_total = sum(info['count'] for info in bins.values())
for etype, info in bins.items():
    print(f"{etype:20s}  {info['fraction']:.1%}  ({info['count']}/{n_total})")

for fname, res in r['results'].items():
    if not res['success']:
        print(f"  FAIL  {fname}  @ {res['error_step']}  {res['error_type']}: {res['error_msg']}")
# Out:
# passed                66.0%  (66/100)
# ValueError            17.0%  (17/100)
# TypeError             14.0%  (14/100)
# AttributeError        2.0%  (2/100)
# SyntaxError           1.0%  (1/100)
#   FAIL  20251218_033650_brass_spacer_tube_v1.py  @ step5  TypeError: Workplane.workplane() got an unexpected keyword argument 'center'
#   FAIL  20251218_033652_grip_handle_spacer_v1.py  @ step4  ValueError: Null TopoDS_Shape object
#   FAIL  20251218_033655_pyramid_with_rounded_base_v1.py  @ step2  TypeError: Workplane.polygon() got an unexpected keyword argument 'points'
#   FAIL  20251218_033657__panel_v1.py  @ step5  ValueError: Null TopoDS_Shape object
#   FAIL  20251218_033657__quick_coupler_v1.py  @ result  TypeError: unsupported operand type(s) for +: 'Assembly' and 'Assembly'
#   FAIL  20251218_033658__mounting_v1.py  @ step7  TypeError: SetFuzzyValue(): incompatible function arguments. The following argument types are supported:
# ...

# %% [markdown]
# # QWEN-2.5

# %%
from metrics import code_pass_rate

bins = code_error_bins("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/qwen2.5-vl-72b-instruct")
r = code_pass_rate("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/qwen2.5-vl-72b-instruct")

n_total = sum(info['count'] for info in bins.values())
for etype, info in bins.items():
    print(f"{etype:20s}  {info['fraction']:.1%}  ({info['count']}/{n_total})")

for fname, res in r['results'].items():
    if not res['success']:
        print(f"  FAIL  {fname}  @ {res['error_step']}  {res['error_type']}: {res['error_msg']}")
# Out:
# passed                98.0%  (98/100)
# AttributeError        1.0%  (1/100)
# ValueError            1.0%  (1/100)
#   FAIL  20251218_033701_base_plate_with_slots_v1.py  @ step5  AttributeError: 'Workplane' object has no attribute 'slot2Point'
#   FAIL  20251218_033715_tapered_post_base_v1.py  @ step4  ValueError: Can not return the Nth element of an empty list

# %% [markdown]
# # Claude Sonnet 3.5

# %%
from metrics import code_pass_rate

bins = code_error_bins("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/claude-3.5-sonnet")
r = code_pass_rate("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/claude-3.5-sonnet")

n_total = sum(info['count'] for info in bins.values())
for etype, info in bins.items():
    print(f"{etype:20s}  {info['fraction']:.1%}  ({info['count']}/{n_total})")

for fname, res in r['results'].items():
    if not res['success']:
        print(f"  FAIL  {fname}  @ {res['error_step']}  {res['error_type']}: {res['error_msg']}")
# Out:
# passed                8.0%  (8/100)
# SyntaxError           87.0%  (87/100)
# IndentationError      3.0%  (3/100)
# TypeError             1.0%  (1/100)
# AttributeError        1.0%  (1/100)
#   FAIL  20251218_033650_brass_spacer_tube_v1.py  @ step3  SyntaxError: unexpected EOF while parsing (<string>, line 1)
#   FAIL  20251218_033651_dowel_pin_brass_v1.py  @ step1  SyntaxError: '(' was never closed (<string>, line 1)
#   FAIL  20251218_033652_grip_handle_spacer_v1.py  @ step2  SyntaxError: unexpected EOF while parsing (<string>, line 1)
#   FAIL  20251218_033652_hook_bracket_v1.py  @ step1  SyntaxError: '(' was never closed (<string>, line 1)
#   FAIL  20251218_033654__sliding_joint_v1.py  @ step2  SyntaxError: unexpected EOF while parsing (<string>, line 1)
#   FAIL  20251218_033654_box_with_fillet_v1.py  @ step2  SyntaxError: unexpected EOF while parsing (<string>, line 1)
# ...

# %% [markdown]
# # Llama-4 Maverick

# %%
from metrics import code_pass_rate

bins = code_error_bins("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/llama-4-maverick")
r = code_pass_rate("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/llama-4-maverick")

n_total = sum(info['count'] for info in bins.values())
for etype, info in bins.items():
    print(f"{etype:20s}  {info['fraction']:.1%}  ({info['count']}/{n_total})")

for fname, res in r['results'].items():
    if not res['success']:
        print(f"  FAIL  {fname}  @ {res['error_step']}  {res['error_type']}: {res['error_msg']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from metrics import code_pass_rate
# ----> 3 bins = code_error_bins("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/llama-4-maverick")
#       4 r = code_pass_rate("/Users/dario/Dropbox/PROJECTS/ML/CAD/generated/llama-4-maverick")
#       6 n_total = sum(info['count'] for info in bins.values())
#
# NameError: name 'code_error_bins' is not defined
